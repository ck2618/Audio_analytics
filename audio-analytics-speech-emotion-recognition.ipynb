# %% [markdown]
# # Speech Emotion Recognition (SER)
#
# <br>
#
# * This notebook serves as an introduction to process audio data to predict user emotions.
# > "Speech Emotion Recognition (SER) is one of the most challenging tasks in speech signal analysis domain, it is a research area problem which tries to infer the emotion from the speech signals. The importance of emotion recognition is getting popular with improving user experience and the engagement of Voice User Interfaces (VUIs) (e.g., smart speaker assistance). For example, customer services, recommender systems, and healthcare applications."
#
# <div><center><img src="https://camo.githubusercontent.com/d7ecf631b87e28e81820007e46b77650b51e2f756ab90849312b4fb3510371d5/68747470733a2f2f692e696d6775722e636f6d2f663154717669542e6a706567" width="600px"/>
# Tonal Emotions(source:MevonAI,https://tinyurl.com/ze94b7ud)</center></div>

# %% [markdown]
# ## A. Importing the required Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # to use operating system dependent functionality
import librosa # to extract speech features
import wave # read and write WAV files
import matplotlib.pyplot as plt # to generate the visualizations

# MLP Classifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# LSTM Classifier
import keras
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import *
from keras.optimizers import rmsprop
# Out:
# Using TensorFlow backend.

# %% [markdown]
# **RAVDESS Dataset Description**
#
# We will use Speech audio-only files (16bit, 48kHz .wav) from the Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS) dataset. This portion of the RAVDESS contains 1440 files: 60 trials per actor x 24 actors = 1440. The RAVDESS contains 24 professional actors (12 female, 12 male), vocalizing two lexically-matched statements in a neutral North American accent. Speech emotions includes calm, happy, sad, angry, fearful, surprise, and disgust expressions. Each expression is produced at two levels of emotional intensity (normal, strong), with an additional neutral expression. **for More details:** (https://www.kaggle.com/uwrfkaggler/ravdess-emotional-speech-audio)

# %% [markdown]
# ## B. Reading the Dataset & Feature Extraction

# %% [markdown]
# **What is Mel-frequency Cepstrum Coefficients (MFCC)?**
# > The sounds generated by a human are filtered by the shape of the vocal tract including tongue, teeth etc. This shape determines what sound comes out. If we can determine the shape accurately, this should give us an accurate representation of the phoneme being produced. The shape of the vocal tract manifests itself in the envelope of the short time power spectrum, and the job of MFCCs is to accurately represent this envelope. **More Details: (https://tinyurl.com/o88j3um)**
# ![Mel-frequency Cepstrum Coefficients](https://miro.medium.com/max/3430/1*pzE4i1TXaLCmzTXgdxFZjQ.jpeg)

# %%
def extract_mfcc(wav_file_name):
    #This function extracts mfcc features and obtain the mean of each dimension
    #Input : path_to_wav_file
    #Output: mfcc_features'''
    y, sr = librosa.load(wav_file_name)
    mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T,axis=0)
    
    return mfccs

# %% [markdown]
# **Note:** The execution time of the following code may take few minutes to finish loading and preprocessing a subset of the dataset, and you can use the entire dataset to enhance the models accuracy.

# %%
##### load radvess speech dataset #####
radvess_speech_labels = [] # to save extracted label/file
ravdess_speech_data = [] # to save extracted features/file
subset_dirs_list = ['Actor_01', 'Actor_02', 'Actor_03','Actor_04', 'Actor_05', 'Actor_06','Actor_07', 'Actor_08']

for dirname, dirs, filenames in os.walk('/kaggle/input/ravdess-emotional-speech-audio/'):
    dirs[:] = [d for d in dirs if d in subset_dirs_list] # you can remove it to train the model over the entire dataset 
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        radvess_speech_labels.append(int(filename[7:8]) - 1) # the index 7 and 8 of the file name represent the emotion label
        wav_file_name = os.path.join(dirname, filename)
        ravdess_speech_data.append(extract_mfcc(wav_file_name)) # extract MFCC features/file
        
print("Finish Loading the Dataset")
# Out:
# Finish Loading the Dataset

# %% [markdown]
# **Preparing the dataset for machine learning models**

# %%
#### convert data and label to array
ravdess_speech_data_array = np.asarray(ravdess_speech_data) # convert the input to an array
ravdess_speech_label_array = np.array(radvess_speech_labels)
ravdess_speech_label_array.shape # get tuple of array dimensions

#### make categorical labels
labels_categorical = to_categorical(ravdess_speech_label_array) # converts a class vector (integers) to binary class matrix
ravdess_speech_data_array.shape
labels_categorical.shape
print(ravdess_speech_label_array.shape, ravdess_speech_data_array.shape, labels_categorical.shape)
# Out:
# (480,) (480, 40) (480, 8)

# %% [markdown]
# ## C. Train and Test MLP Classifier

# %% [markdown]
# *  Split the dataset into training and testing sets: (training set) a subset to train a model, (test set) a subset to test the trained model.
# *  **Note:**(train_test_split) function will split arrays or matrices into random train and test subsets, in our example, training set 80% and testing set 20%

# %%
x_train,x_test,y_train,y_test= train_test_split(np.array(ravdess_speech_data_array),labels_categorical, test_size=0.20, random_state=9)

# %% [markdown]
# * **What is A multilayer perceptron (MLP)?**
# * A multilayer perceptron (MLP) is a deep, artificial neural network. It is composed of more than one perceptron. They are composed of an input layer to receive the signal, an output layer that makes a decision or prediction about the input, and in between those two, an arbitrary number of hidden layers that are the true computational engine of the MLP. **More Details:** (https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html)

# %% [markdown]
# * Define MLP and adjust its **hyperparameter** (a parameter whose value is set before the learning process begins.)

# %%
# Initialize the Multi Layer Perceptron Classifier
model=MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08, hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=500)

# %% [markdown]
# * **Trains the model for a fixed number of epochs (iterations on a dataset).**

# %%
# Train the model
model.fit(x_train,y_train)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(activation='relu', alpha=0.01, batch_size=256, beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(300,), learning_rate='adaptive',
#               learning_rate_init=0.001, max_fun=15000, max_iter=500,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %% [markdown]
# *  **Generates output predictions for the input samples.**

# %%
# Predict for the test set
y_pred=model.predict(x_test)

# %% [markdown]
# *  **(accuracy)**: is a function that is used to judge the performance of your model.

# %%
# Calculate the accuracy of our model
accuracy=accuracy_score(y_true=y_test, y_pred=y_pred)
# Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 55.21%

# %% [markdown]
# We have obtained **09.38% accuracy** (depend on the execution) by using MLP as classifier, but this is can be improved by adjusting the training hyperparameter, increasing the dataset, or trying other machine learning models.

# %% [markdown]
# ## D. Train and Test LSTM Classifier
#
# > In this example, we will use another model to improve the accuracy which is LSTM model.

# %% [markdown]
# * **What is Long short-term memory (LSTM)?**
#
# Recurrent neural networks, of which LSTMs are the most powerful and well known subset, are a type of artificial neural network designed to recognize patterns in sequences of data, such as text, genomes, handwriting and the spoken word. **More Details:** (https://keras.io/layers/recurrent/#lstm) (Understanding LSTM Networks:https://tinyurl.com/pbamomv)

# %%
# Split the training, validating, and testing sets
number_of_samples = ravdess_speech_data_array.shape[0]
training_samples = int(number_of_samples * 0.8)
validation_samples = int(number_of_samples * 0.1)
test_samples = int(number_of_samples * 0.1)

# %%
# Define the LSTM model
def create_model_LSTM():
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=(40, 1)))
    model.add(Dense(64))
    model.add(Dropout(0.4))
    model.add(Activation('relu'))
    model.add(Dense(32))
    model.add(Dropout(0.4))
    model.add(Activation('relu'))
    model.add(Dense(8))
    model.add(Activation('softmax'))
    
    # Configures the model for training
    model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    return model

# %%
### train using LSTM model
model_A = create_model_LSTM()
history = model_A.fit(np.expand_dims(ravdess_speech_data_array[:training_samples],-1), labels_categorical[:training_samples], validation_data=(np.expand_dims(ravdess_speech_data_array[training_samples:training_samples+validation_samples], -1), labels_categorical[training_samples:training_samples+validation_samples]), epochs=100, shuffle=True)
# Out:
# Train on 384 samples, validate on 48 samples
# Epoch 1/100
# 384/384 [==============================] - 2s 4ms/step - loss: 2.0764 - accuracy: 0.1172 - val_loss: 2.0671 - val_accuracy: 0.1458
# Epoch 2/100
# 384/384 [==============================] - 1s 1ms/step - loss: 2.0713 - accuracy: 0.1484 - val_loss: 2.0603 - val_accuracy: 0.1667
# Epoch 3/100
# 384/384 [==============================] - 1s 1ms/step - loss: 2.0507 - accuracy: 0.1589 - val_loss: 2.0597 - val_accuracy: 0.1875
# Epoch 4/100
# 384/384 [==============================] - 1s 1ms/step - loss: 2.0448 - accuracy: 0.1797 - val_loss: 2.0488 - val_accuracy: 0.1667
# Epoch 5/100
# 384/384 [==============================] - 1s 1ms/step - loss: 2.0072 - accuracy: 0.2188 - val_loss: 2.0389 - val_accuracy: 0.1667
# Epoch 6/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.9858 - accuracy: 0.2109 - val_loss: 2.0069 - val_accuracy: 0.1458
# Epoch 7/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.9407 - accuracy: 0.2526 - val_loss: 2.0034 - val_accuracy: 0.2083
# Epoch 8/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.9395 - accuracy: 0.2578 - val_loss: 1.9784 - val_accuracy: 0.2083
# Epoch 9/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.8854 - accuracy: 0.2526 - val_loss: 1.9504 - val_accuracy: 0.1667
# Epoch 10/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.8769 - accuracy: 0.2552 - val_loss: 2.1150 - val_accuracy: 0.1458
# Epoch 11/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.9429 - accuracy: 0.2031 - val_loss: 1.9691 - val_accuracy: 0.2083
# Epoch 12/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.8723 - accuracy: 0.2656 - val_loss: 1.9969 - val_accuracy: 0.2292
# Epoch 13/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.8187 - accuracy: 0.2943 - val_loss: 1.9490 - val_accuracy: 0.2708
# Epoch 14/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.7868 - accuracy: 0.3151 - val_loss: 1.9636 - val_accuracy: 0.2292
# Epoch 15/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.7799 - accuracy: 0.2995 - val_loss: 1.9470 - val_accuracy: 0.2917
# Epoch 16/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.7637 - accuracy: 0.3047 - val_loss: 1.9715 - val_accuracy: 0.2500
# Epoch 17/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.7478 - accuracy: 0.3073 - val_loss: 1.9528 - val_accuracy: 0.2708
# Epoch 18/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.7787 - accuracy: 0.2891 - val_loss: 1.9622 - val_accuracy: 0.2917
# Epoch 19/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.7190 - accuracy: 0.3073 - val_loss: 2.0245 - val_accuracy: 0.2083
# Epoch 20/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6715 - accuracy: 0.3672 - val_loss: 2.0330 - val_accuracy: 0.1875
# Epoch 21/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6488 - accuracy: 0.3542 - val_loss: 1.9930 - val_accuracy: 0.2917
# Epoch 22/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6753 - accuracy: 0.3229 - val_loss: 1.9776 - val_accuracy: 0.2083
# Epoch 23/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6671 - accuracy: 0.3620 - val_loss: 1.9859 - val_accuracy: 0.2083
# Epoch 24/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6715 - accuracy: 0.3490 - val_loss: 1.9564 - val_accuracy: 0.2708
# Epoch 25/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6780 - accuracy: 0.3594 - val_loss: 1.9873 - val_accuracy: 0.2500
# Epoch 26/100
# 384/384 [==============================] - 0s 1ms/step - loss: 1.6242 - accuracy: 0.3698 - val_loss: 2.0174 - val_accuracy: 0.2083
# Epoch 27/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6627 - accuracy: 0.3490 - val_loss: 1.9872 - val_accuracy: 0.2708
# Epoch 28/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6219 - accuracy: 0.3385 - val_loss: 1.9747 - val_accuracy: 0.2083
# Epoch 29/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.5541 - accuracy: 0.3854 - val_loss: 2.0313 - val_accuracy: 0.2083
# Epoch 30/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.5878 - accuracy: 0.3776 - val_loss: 2.1593 - val_accuracy: 0.1667
# Epoch 31/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.5794 - accuracy: 0.3776 - val_loss: 2.0122 - val_accuracy: 0.2708
# Epoch 32/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.5739 - accuracy: 0.3932 - val_loss: 2.0389 - val_accuracy: 0.2708
# Epoch 33/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6152 - accuracy: 0.3594 - val_loss: 2.0691 - val_accuracy: 0.2292
# Epoch 34/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.5067 - accuracy: 0.4089 - val_loss: 2.0237 - val_accuracy: 0.2500
# Epoch 35/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.5323 - accuracy: 0.3906 - val_loss: 2.0893 - val_accuracy: 0.1667
# Epoch 36/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.6019 - accuracy: 0.3490 - val_loss: 2.0894 - val_accuracy: 0.1667
# Epoch 37/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.4875 - accuracy: 0.4193 - val_loss: 2.0319 - val_accuracy: 0.2708
# Epoch 38/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.5178 - accuracy: 0.3906 - val_loss: 2.0825 - val_accuracy: 0.2500
# Epoch 39/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.4906 - accuracy: 0.4036 - val_loss: 2.0888 - val_accuracy: 0.2917
# Epoch 40/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.5326 - accuracy: 0.4062 - val_loss: 2.0998 - val_accuracy: 0.3125
# Epoch 41/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.5362 - accuracy: 0.3594 - val_loss: 2.1659 - val_accuracy: 0.2292
# Epoch 42/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.4674 - accuracy: 0.4141 - val_loss: 2.1055 - val_accuracy: 0.2500
# Epoch 43/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.4622 - accuracy: 0.4036 - val_loss: 2.1208 - val_accuracy: 0.2917
# Epoch 44/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.4662 - accuracy: 0.4297 - val_loss: 2.1830 - val_accuracy: 0.2292
# Epoch 45/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.4297 - accuracy: 0.4323 - val_loss: 2.1733 - val_accuracy: 0.2708
# Epoch 46/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.4341 - accuracy: 0.4297 - val_loss: 2.1816 - val_accuracy: 0.2292
# Epoch 47/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.4727 - accuracy: 0.4401 - val_loss: 2.1647 - val_accuracy: 0.2083
# Epoch 48/100
# 384/384 [==============================] - 0s 1ms/step - loss: 1.4270 - accuracy: 0.4427 - val_loss: 2.1859 - val_accuracy: 0.2500
# Epoch 49/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.3835 - accuracy: 0.4766 - val_loss: 2.1741 - val_accuracy: 0.2500
# Epoch 50/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.4257 - accuracy: 0.4557 - val_loss: 2.1699 - val_accuracy: 0.1667
# Epoch 51/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.3829 - accuracy: 0.4349 - val_loss: 2.3098 - val_accuracy: 0.1875
# Epoch 52/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.3466 - accuracy: 0.4505 - val_loss: 2.1749 - val_accuracy: 0.3125
# Epoch 53/100
# 384/384 [==============================] - 0s 1ms/step - loss: 1.3630 - accuracy: 0.4557 - val_loss: 2.1616 - val_accuracy: 0.2083
# Epoch 54/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.3148 - accuracy: 0.4714 - val_loss: 2.2359 - val_accuracy: 0.1458
# Epoch 55/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.3396 - accuracy: 0.5000 - val_loss: 2.2360 - val_accuracy: 0.2292
# Epoch 56/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.3503 - accuracy: 0.4349 - val_loss: 2.2539 - val_accuracy: 0.1667
# Epoch 57/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.3081 - accuracy: 0.4922 - val_loss: 2.2218 - val_accuracy: 0.2292
# Epoch 58/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.2873 - accuracy: 0.5182 - val_loss: 2.2469 - val_accuracy: 0.2708
# Epoch 59/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.3100 - accuracy: 0.4688 - val_loss: 2.3942 - val_accuracy: 0.2500
# Epoch 60/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.3400 - accuracy: 0.4922 - val_loss: 2.3109 - val_accuracy: 0.1875
# Epoch 61/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.2352 - accuracy: 0.5104 - val_loss: 2.4305 - val_accuracy: 0.1667
# Epoch 62/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.2013 - accuracy: 0.5234 - val_loss: 2.2485 - val_accuracy: 0.2917
# Epoch 63/100
# 384/384 [==============================] - 1s 2ms/step - loss: 1.3034 - accuracy: 0.4870 - val_loss: 2.2757 - val_accuracy: 0.2917
# Epoch 64/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.2628 - accuracy: 0.4974 - val_loss: 2.3858 - val_accuracy: 0.2292
# Epoch 65/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.2538 - accuracy: 0.4688 - val_loss: 2.3533 - val_accuracy: 0.2917
# Epoch 66/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.2083 - accuracy: 0.5234 - val_loss: 2.3609 - val_accuracy: 0.2917
# Epoch 67/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1875 - accuracy: 0.5208 - val_loss: 2.3809 - val_accuracy: 0.2917
# Epoch 68/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1734 - accuracy: 0.5339 - val_loss: 2.4658 - val_accuracy: 0.1875
# Epoch 69/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1982 - accuracy: 0.5391 - val_loss: 2.5179 - val_accuracy: 0.2500
# Epoch 70/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.2625 - accuracy: 0.5208 - val_loss: 2.6961 - val_accuracy: 0.0833
# Epoch 71/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.2741 - accuracy: 0.4766 - val_loss: 2.4175 - val_accuracy: 0.1875
# Epoch 72/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1731 - accuracy: 0.5521 - val_loss: 2.5316 - val_accuracy: 0.1667
# Epoch 73/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1204 - accuracy: 0.5599 - val_loss: 2.5297 - val_accuracy: 0.1875
# Epoch 74/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1704 - accuracy: 0.5312 - val_loss: 2.4351 - val_accuracy: 0.2500
# Epoch 75/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1436 - accuracy: 0.5625 - val_loss: 2.3884 - val_accuracy: 0.1875
# Epoch 76/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.0874 - accuracy: 0.5833 - val_loss: 2.4930 - val_accuracy: 0.2292
# Epoch 77/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.0574 - accuracy: 0.5677 - val_loss: 2.6734 - val_accuracy: 0.2292
# Epoch 78/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.0693 - accuracy: 0.5859 - val_loss: 2.8220 - val_accuracy: 0.1250
# Epoch 79/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.0991 - accuracy: 0.5495 - val_loss: 2.6819 - val_accuracy: 0.1458
# Epoch 80/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.0809 - accuracy: 0.5677 - val_loss: 2.7332 - val_accuracy: 0.2500
# Epoch 81/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1165 - accuracy: 0.5365 - val_loss: 2.6385 - val_accuracy: 0.1875
# Epoch 82/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.0648 - accuracy: 0.5859 - val_loss: 2.6707 - val_accuracy: 0.1667
# Epoch 83/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1027 - accuracy: 0.5547 - val_loss: 2.5143 - val_accuracy: 0.1875
# Epoch 84/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.1852 - accuracy: 0.5365 - val_loss: 2.6518 - val_accuracy: 0.1458
# Epoch 85/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.0347 - accuracy: 0.5990 - val_loss: 2.6181 - val_accuracy: 0.1667
# Epoch 86/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.0856 - accuracy: 0.5911 - val_loss: 2.5650 - val_accuracy: 0.2292
# Epoch 87/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9965 - accuracy: 0.6146 - val_loss: 2.5052 - val_accuracy: 0.2292
# Epoch 88/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9489 - accuracy: 0.6406 - val_loss: 2.9170 - val_accuracy: 0.1458
# Epoch 89/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9494 - accuracy: 0.6432 - val_loss: 2.7725 - val_accuracy: 0.2083
# Epoch 90/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9500 - accuracy: 0.6276 - val_loss: 2.8062 - val_accuracy: 0.1875
# Epoch 91/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9747 - accuracy: 0.6172 - val_loss: 2.7692 - val_accuracy: 0.2083
# Epoch 92/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9830 - accuracy: 0.6172 - val_loss: 2.8914 - val_accuracy: 0.2292
# Epoch 93/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9347 - accuracy: 0.6302 - val_loss: 2.8922 - val_accuracy: 0.1875
# Epoch 94/100
# 384/384 [==============================] - 0s 1ms/step - loss: 0.9642 - accuracy: 0.6510 - val_loss: 2.8822 - val_accuracy: 0.1667
# Epoch 95/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.8851 - accuracy: 0.6615 - val_loss: 2.8023 - val_accuracy: 0.2083
# Epoch 96/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.8859 - accuracy: 0.6797 - val_loss: 2.8623 - val_accuracy: 0.2292
# Epoch 97/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9782 - accuracy: 0.6068 - val_loss: 2.9430 - val_accuracy: 0.1667
# Epoch 98/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9163 - accuracy: 0.6224 - val_loss: 3.1157 - val_accuracy: 0.1458
# Epoch 99/100
# 384/384 [==============================] - 1s 1ms/step - loss: 1.0194 - accuracy: 0.6172 - val_loss: 2.8281 - val_accuracy: 0.2708
# Epoch 100/100
# 384/384 [==============================] - 1s 1ms/step - loss: 0.9662 - accuracy: 0.6120 - val_loss: 2.9233 - val_accuracy: 0.1875

# %%
### loss plots using LSTM model
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
### accuracy plots using LSTM model
plt.clf()                                                

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'ro', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()

plt.show()

# %% [markdown]
# *  **(evaluate function): Returns the loss value & metrics values for the model in test mode.**

# %%
### evaluate using model A
model_A.evaluate(np.expand_dims(ravdess_speech_data_array[training_samples + validation_samples:], -1), labels_categorical[training_samples + validation_samples:])
# Out:
# 48/48 [==============================] - 0s 423us/step
# [3.280383745829264, 0.2708333432674408]

# %% [markdown]
# * **Save the weights of the model as a HDF5 file**

# %%
model_A.save_weights("Model_LSTM.h5")

# %% [markdown]
# ## E. Credits and Further Reading
# 1. Audio and music processing in Python, https://librosa.org
# 2. ML/DL and audio analysis, https://towardsdatascience.com/how-to-apply-machine-learning-and-deep-learning-methods-to-audio-analysis-615e286fcbbc
# 3. Sound classification, https://medium.com/@mikesmales/sound-classification-using-deep-learning-8bc2aa1990b7
